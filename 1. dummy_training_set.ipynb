# %%
import pandas as pd
import numpy as np
df = pd.read_excel('Blacklist & outgoing.xlsx', 'Sheet2')

# %%
df = df[df['anum_ispstn'] == 1]
df.reset_index()
# Out:
#      index       inserted_date           call_time            end_time  \
# 0       76 2023-11-08 00:31:01 2023-11-07 23:50:35 2023-11-07 23:51:08
# 1      109 2023-11-08 00:31:06 2023-11-08 00:05:48 2023-11-08 00:06:00
# 2      111 2023-11-08 00:31:06 2023-11-08 00:06:19 2023-11-08 00:06:31
# 3      115 2023-11-08 00:31:06 2023-11-08 00:06:05 2023-11-08 00:06:18
# 4      119 2023-11-08 00:31:07 2023-11-08 00:07:15 2023-11-08 00:07:27
# ..     ...                 ...                 ...                 ...
# 502   4837 2023-11-08 08:30:39 2023-11-08 08:05:10 2023-11-08 08:05:18
# 503   4838 2023-11-08 08:30:39 2023-11-08 08:05:32 2023-11-08 08:05:40
# 504   4849 2023-11-08 08:30:39 2023-11-08 08:07:26 2023-11-08 08:10:17
# 505   4855 2023-11-08 08:30:39 2023-11-08 08:08:27 2023-11-08 08:11:43
# 506   4860 2023-11-08 08:30:39 2023-11-08 08:11:28 2023-11-08 08:12:35
#
#            process_time        anum           bnum trunkin trunkout  duration  \
# 0   2023-11-08 00:30:43  2180648711    33670077510  BDJK2G   IJHPSG        30
# 1   2023-11-08 00:30:43   211071077    33147205010  BIOAC1   GCTHKG         5
# 2   2023-11-08 00:30:43   211071077    33147205010  BIOAC1   GCTHKG         5
# 3   2023-11-08 00:30:43   211071077    33147205010  BIOAC1   GCTHKG         5
# 4   2023-11-08 00:30:43   211071077    33147205010  BIOAC1   GCTHKG         5
# ..                  ...         ...            ...     ...      ...       ...
# 502 2023-11-08 08:30:18  6125141134  4316999408202  BDJK2G   IJHPSG         4
# 503 2023-11-08 08:30:18  6125141134    46771191170  BDJK2G   IJHPSG         6
# 504 2023-11-08 08:30:20  2131174017   971550958236  BITL1P   IJHTSP       155
# 505 2023-11-08 08:30:20  2486005790    94772484573  BDJK1G   IJHPSG       171
# 506 2023-11-08 08:30:20   212314846    31624026631  BITL1P   IJHTSP        59
#
#      ... bnum_pstn_prefix bnum_pstn_province  bnum_pstn_city anum_pstn_prefix  \
# 0    ...              NaN                NaN             NaN             21.0
# 1    ...              NaN                NaN             NaN             21.0
# 2    ...              NaN                NaN             NaN             21.0
# 3    ...              NaN                NaN             NaN             21.0
# 4    ...              NaN                NaN             NaN             21.0
# ..   ...              ...                ...             ...              ...
# 502  ...              NaN                NaN             NaN             61.0
# 503  ...              NaN                NaN             NaN             61.0
# 504  ...              NaN                NaN             NaN             21.0
# 505  ...              NaN                NaN             NaN             24.0
# 506  ...              NaN                NaN             NaN             21.0
#
#     anum_pstn_province                                     anum_pstn_city  \
# 0            JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# 1            JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# 2            JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# 3            JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# 4            JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# ..                 ...                                                ...
# 502     Sumatera Utara                                         Kota Medan
# 503     Sumatera Utara                                         Kota Medan
# 504          JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
# 505        Jawa Tengah             Semarang Ungaran Demak Mranggen Sayung
# 506          JADETABEK  Jakarta  Tigaraksa Kabupaten Tangerang  Kota B...
#
#     netasource central  central_type        ds
# 0          NaN     NaN           NaN  20231108
# 1          NaN     NaN           NaN  20231108
# 2          NaN     NaN           NaN  20231108
# 3          NaN     NaN           NaN  20231108
# 4          NaN     NaN           NaN  20231108
# ..         ...     ...           ...       ...
# 502        NaN     NaN           NaN  20231108
# 503        NaN     NaN           NaN  20231108
# 504        NaN     NaN           NaN  20231108
# 505        NaN     NaN           NaN  20231108
# 506        NaN     NaN           NaN  20231108
#
# [507 rows x 74 columns]

# %%
# Melakukan grouping berdasarkan anum dan bnum yang sama dengan menjumlahkan duration dan menghitung count
df['count'] = 0
result_baru = pd.DataFrame()
result_baru = df.groupby(['anum', 'bnum']).agg({'duration': 'sum', 'count': 'size'}).reset_index()
result_baru
# Out:
#               anum           bnum  duration  count
# 0         21153489   352621057694        47      1
# 1         64558488  4940611947422         6      1
# 2        211071077      499466207        25      1
# 3        211071077     3289510582       348      1
# 4        211071077     4533480402       198      1
# ..             ...            ...       ...    ...
# 405     7788071005    41556473317         6      1
# 406     7788071099    41812504770       151      1
# 407  2129650800800   971501196089         6      1
# 408  2129650800800   971551604300         5      1
# 409  2129650800800   971562244818      1835      1
#
# [410 rows x 4 columns]

# %%
result_baru
# Out:
#               anum           bnum  duration  count
# 0         21153489   352621057694        47      1
# 1         64558488  4940611947422         6      1
# 2        211071077      499466207        25      1
# 3        211071077     3289510582       348      1
# 4        211071077     4533480402       198      1
# ..             ...            ...       ...    ...
# 405     7788071005    41556473317         6      1
# 406     7788071099    41812504770       151      1
# 407  2129650800800   971501196089         6      1
# 408  2129650800800   971551604300         5      1
# 409  2129650800800   971562244818      1835      1
#
# [410 rows x 4 columns]

# %%
#split antara df1 dan df2
df1 = result_baru.head(200)
df2 = result_baru.tail(210)

# %%
df1
# Out:
#            anum           bnum  duration  count
# 0      21153489   352621057694        47      1
# 1      64558488  4940611947422         6      1
# 2     211071077      499466207        25      1
# 3     211071077     3289510582       348      1
# 4     211071077     4533480402       198      1
# ..          ...            ...       ...    ...
# 195  2130762440    31624022321        14      1
# 196  2130762440   905429820753        15      1
# 197  2130762526   905328247650        13      1
# 198  2130764109  4917201215926         1      1
# 199  2131109538     4528130246        58      1
#
# [200 rows x 4 columns]

# %%
import random

def dummy(df1):
  for i in range(len(df1)):
    df1.at[i, 'duration'] = df1.at[i, 'duration'] + random.randint(100,500)
    df1.at[i, 'count'] = df1.at[i, 'count'] + random.randint(0,2)

  return df1

# %%
# melakukan manipulasi data pada df1
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)
df1 = dummy(df1)

# %%
df1
# Out:
#            anum           bnum  duration  count
# 0      21153489   352621057694      2794      7
# 1      64558488  4940611947422      2455     10
# 2     211071077      499466207      2564      6
# 3     211071077     3289510582      2773     11
# 4     211071077     4533480402      2215      8
# ..          ...            ...       ...    ...
# 195  2130762440    31624022321      2550      7
# 196  2130762440   905429820753      2124      8
# 197  2130762526   905328247650      2310     10
# 198  2130764109  4917201215926      2395      8
# 199  2131109538     4528130246      2244      8
#
# [200 rows x 4 columns]

# %%
# menyatukan df1 yang telah dimanipulasi dengan df2
result_baru = pd.concat([df1, df2], ignore_index=True)

# %%
# melakukan filterasi nilai count >= 5 dan duration >= 2400
result_baru[(result_baru['count'] >= 5) & (result_baru['duration'] >=2400)]
# Out:
#            anum           bnum  duration  count
# 0      21153489   352621057694      2794      7
# 1      64558488  4940611947422      2455     10
# 2     211071077      499466207      2564      6
# 3     211071077     3289510582      2773     11
# 5     211071077     6703324502      3149     11
# ..          ...            ...       ...    ...
# 190  2130420500   639170119515      2520      5
# 192  2130481270    63288339999      3092     10
# 193  2130481930   905429702786      2735      7
# 194  2130488987   971500202461      2421      5
# 195  2130762440    31624022321      2550      7
#
# [141 rows x 4 columns]

# %% [markdown]
# Mengikuti langkah-langkah pada feature engineer untuk mendapatkan feature yang sesuai

# %%
result_baru_new = pd.DataFrame()
result_baru_new = result_baru.groupby('anum').agg({'duration': 'sum', 'count': 'size'}).reset_index()
result_baru_new.rename(columns={'duration': 'total_duration', 'count' : 'diff_call'}, inplace=True)
result_baru_new
# Out:
#               anum  total_duration  diff_call
# 0         21153489            2794          1
# 1         64558488            2455          1
# 2        211071077           35417         13
# 3        212305608            2142          1
# 4        212314846            2408          1
# ..             ...             ...        ...
# 282     7785709077             321          1
# 283     7787711503              20          1
# 284     7788071005               6          1
# 285     7788071099             151          1
# 286  2129650800800            1846          3
#
# [287 rows x 3 columns]

# %%
result_inner = pd.DataFrame()
result_inner = pd.merge(result_baru, result_baru_new, on='anum', how='inner')
result_inner
# Out:
#               anum           bnum  duration  count  total_duration  diff_call
# 0         21153489   352621057694      2794      7            2794          1
# 1         64558488  4940611947422      2455     10            2455          1
# 2        211071077      499466207      2564      6           35417         13
# 3        211071077     3289510582      2773     11           35417         13
# 4        211071077     4533480402      2215      8           35417         13
# ..             ...            ...       ...    ...             ...        ...
# 405     7788071005    41556473317         6      1               6          1
# 406     7788071099    41812504770       151      1             151          1
# 407  2129650800800   971501196089         6      1            1846          3
# 408  2129650800800   971551604300         5      1            1846          3
# 409  2129650800800   971562244818      1835      1            1846          3
#
# [410 rows x 6 columns]

# %%
result_baru_new_2 = pd.DataFrame()
result_baru_new_2 = result_inner.groupby('anum').agg({'count': 'sum'}).reset_index()
result_baru_new_2.rename(columns={'count': 'total_call'}, inplace=True)
result_baru_new_2
# Out:
#               anum  total_call
# 0         21153489           7
# 1         64558488          10
# 2        211071077         116
# 3        212305608           5
# 4        212314846           7
# ..             ...         ...
# 282     7785709077           1
# 283     7787711503           1
# 284     7788071005           1
# 285     7788071099           1
# 286  2129650800800           3
#
# [287 rows x 2 columns]

# %%
result_inner_2 = pd.DataFrame()
result_inner_2 = pd.merge(result_inner, result_baru_new_2, on='anum', how='inner')
result_inner_2['is_fraud'] = 0
result_inner_2
# Out:
#               anum           bnum  duration  count  total_duration  diff_call  \
# 0         21153489   352621057694      2794      7            2794          1
# 1         64558488  4940611947422      2455     10            2455          1
# 2        211071077      499466207      2564      6           35417         13
# 3        211071077     3289510582      2773     11           35417         13
# 4        211071077     4533480402      2215      8           35417         13
# ..             ...            ...       ...    ...             ...        ...
# 405     7788071005    41556473317         6      1               6          1
# 406     7788071099    41812504770       151      1             151          1
# 407  2129650800800   971501196089         6      1            1846          3
# 408  2129650800800   971551604300         5      1            1846          3
# 409  2129650800800   971562244818      1835      1            1846          3
#
#      total_call  is_fraud
# 0             7         0
# 1            10         0
# 2           116         0
# 3           116         0
# 4           116         0
# ..          ...       ...
# 405           1         0
# 406           1         0
# 407           3         0
# 408           3         0
# 409           3         0
#
# [410 rows x 8 columns]

# %%
# memberikan label 1 pada baris yang sesuai dengan rule-based fraud
for i in range(len(result_inner_2)):
  if result_inner_2.iloc[i]['duration'] >= 2400 and result_inner_2.iloc[i]['count'] >=5 :
    result_inner_2.loc[i]['is_fraud'] = 1

# %%
result_train1 = result_inner_2

# %%
# membaca dataset baru untuk penambahan anum dummy
bakal = pd.read_excel('result_baru.xlsx')
bakal = bakal.drop('Unnamed: 0', axis=1)
bakal
# Out:
#               anum           bnum  duration  count
# 0         21153489   352621057694        47      1
# 1         64558488  4940611947422         6      1
# 2        211071077      499466207        25      1
# 3        211071077     3289510582       348      1
# 4        211071077     4533480402       198      1
# ..             ...            ...       ...    ...
# 405     7788071005    41556473317         6      1
# 406     7788071099    41812504770       151      1
# 407  2129650800800   971501196089         6      1
# 408  2129650800800   971551604300         5      1
# 409  2129650800800   971562244818      1835      1
#
# [410 rows x 4 columns]

# %%
df = pd.read_excel('Blacklist & outgoing.xlsx', 'Sheet2')

# %%
anum_unik = df['anum'].unique()
len(anum_unik)
# Out:
# 2974

# %%
bnum_unik = df['bnum'].unique()
bnum_unik
# Out:
# array([441179359421,  33603187565,  33762076648, ...,  15877690898,
#         67078418056, 522949410153])

# %%
bakal_unik = bakal['anum'].unique()

# %%
# menambah dummy baru
for i in range(2974):
  if anum_unik[i] not in bakal_unik:
    bakal.loc[len(bakal)] = {'anum': anum_unik[i], 'bnum': np.random.choice(bnum_unik),
                             'duration': np.random.randint(1, 100), 'count': np.random.randint(1, 11)}

# %%
bakal
# Out:
#              anum           bnum  duration  count
# 0        21153489   352621057694        47      1
# 1        64558488  4940611947422         6      1
# 2       211071077      499466207        25      1
# 3       211071077     3289510582       348      1
# 4       211071077     4533480402       198      1
# ...           ...            ...       ...    ...
# 3092   8124804043    18087436331        91      1
# 3093  82311120209   905429702357        22      1
# 3094  81237250184   639177026554        24      8
# 3095  19046166160    96899112229        82      2
# 3096  85219813625    34629398886        58      1
#
# [3097 rows x 4 columns]

# %%
# memisahkan data bakal1 dengan bakal2
bakal1 = bakal.head(1000)
bakal2 = bakal.tail(3097-1000)

# %%
# melakukan manipulasi data pada bakal1
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)
bakal1 = dummy(bakal1)

# %%
bakal1
# Out:
#              anum           bnum  duration  count
# 0        21153489   352621057694      2772     12
# 1        64558488  4940611947422      3411     14
# 2       211071077      499466207      3484     14
# 3       211071077     3289510582      2301      9
# 4       211071077     4533480402      3334     13
# ..            ...            ...       ...    ...
# 995  998916036641    33948007018      3246     13
# 996   85873962880    97699028221      2294     16
# 997   81249989919    31646381631      2916     20
# 998  447425859031    49691338930      2612     18
# 999   82145873228    84908751688      3162     11
#
# [1000 rows x 4 columns]

# %%
# menyatukan bakal1 yang telah dimanipulasi dengan bakal2
result_baru = pd.concat([bakal1, bakal2], ignore_index=True)

# %%
# melakukan filterasi nilai count >= 5 dan duration >= 2400
result_baru[(result_baru['count'] >= 5) & (result_baru['duration'] >=2400)]
# Out:
#              anum           bnum  duration  count
# 0        21153489   352621057694      2772     12
# 1        64558488  4940611947422      3411     14
# 2       211071077      499466207      3484     14
# 4       211071077     4533480402      3334     13
# 5       211071077     6703324502      4236     13
# ..            ...            ...       ...    ...
# 994     811107323    67076249580      3129     14
# 995  998916036641    33948007018      3246     13
# 997   81249989919    31646381631      2916     20
# 998  447425859031    49691338930      2612     18
# 999   82145873228    84908751688      3162     11
#
# [967 rows x 4 columns]

# %% [markdown]
# Mengikuti langkah-langkah pada feature engineer untuk mendapatkan feature yang sesuai

# %%
result_baru_new = pd.DataFrame()
result_baru_new = result_baru.groupby('anum').agg({'duration': 'sum', 'count': 'size'}).reset_index()
result_baru_new.rename(columns={'duration': 'total_duration', 'count' : 'diff_call'}, inplace=True)
result_baru_new
# Out:
#                  anum  total_duration  diff_call
# 0                 188            3292          1
# 1               62188            3237          1
# 2             1500070            2566          1
# 3             1500136            2647          1
# 4             1500385            2651          1
# ...               ...             ...        ...
# 2969    8618116375480              55          1
# 2970    8618811402223              55          1
# 2971    8801684100300            3056          1
# 2972  436761821057757              97          1
# 2973  436789070050852              77          1
#
# [2974 rows x 3 columns]

# %%
result_inner = pd.DataFrame()
result_inner = pd.merge(result_baru, result_baru_new, on='anum', how='inner')
result_inner
# Out:
#              anum           bnum  duration  count  total_duration  diff_call
# 0        21153489   352621057694      2772     12            2772          1
# 1        64558488  4940611947422      3411     14            3411          1
# 2       211071077      499466207      3484     14           42675         13
# 3       211071077     3289510582      2301      9           42675         13
# 4       211071077     4533480402      3334     13           42675         13
# ...           ...            ...       ...    ...             ...        ...
# 3092   8124804043    18087436331        91      1              91          1
# 3093  82311120209   905429702357        22      1              22          1
# 3094  81237250184   639177026554        24      8              24          1
# 3095  19046166160    96899112229        82      2              82          1
# 3096  85219813625    34629398886        58      1              58          1
#
# [3097 rows x 6 columns]

# %%
result_baru_new_2 = pd.DataFrame()
result_baru_new_2 = result_inner.groupby('anum').agg({'count': 'sum'}).reset_index()
result_baru_new_2.rename(columns={'count': 'total_call'}, inplace=True)
result_baru_new_2
# Out:
#                  anum  total_call
# 0                 188          11
# 1               62188           6
# 2             1500070          19
# 3             1500136          23
# 4             1500385          14
# ...               ...         ...
# 2969    8618116375480           1
# 2970    8618811402223          10
# 2971    8801684100300          13
# 2972  436761821057757           6
# 2973  436789070050852           8
#
# [2974 rows x 2 columns]

# %%
result_inner_2 = pd.DataFrame()
result_inner_2 = pd.merge(result_inner, result_baru_new_2, on='anum', how='inner')
result_inner_2['is_fraud'] = 0
result_inner_2
# Out:
#              anum           bnum  duration  count  total_duration  diff_call  \
# 0        21153489   352621057694      2772     12            2772          1
# 1        64558488  4940611947422      3411     14            3411          1
# 2       211071077      499466207      3484     14           42675         13
# 3       211071077     3289510582      2301      9           42675         13
# 4       211071077     4533480402      3334     13           42675         13
# ...           ...            ...       ...    ...             ...        ...
# 3092   8124804043    18087436331        91      1              91          1
# 3093  82311120209   905429702357        22      1              22          1
# 3094  81237250184   639177026554        24      8              24          1
# 3095  19046166160    96899112229        82      2              82          1
# 3096  85219813625    34629398886        58      1              58          1
#
#       total_call  is_fraud
# 0             12         0
# 1             14         0
# 2            149         0
# 3            149         0
# 4            149         0
# ...          ...       ...
# 3092           1         0
# 3093           1         0
# 3094           8         0
# 3095           2         0
# 3096           1         0
#
# [3097 rows x 8 columns]

# %%
# memberikan label 1 pada baris yang sesuai dengan rule-based fraud
for i in range(len(result_inner_2)):
  if result_inner_2.iloc[i]['duration'] >= 2400 and result_inner_2.iloc[i]['count'] >=5 :
    result_inner_2.loc[i]['is_fraud'] = 1

# %%
result_train2 = result_inner_2

# %%
# menyatukan data asli yang telah melakukan feature engineer dengan data dummy
result_dummy = pd.concat([result_train1, result_train2], ignore_index=True)

# %%
result_dummy.to_excel('result_dummy.xlsx')
